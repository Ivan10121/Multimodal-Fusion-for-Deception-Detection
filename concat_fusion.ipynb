# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader, random_split, Dataset
from torch.optim.lr_scheduler import ReduceLROnPlateau
import random

# %%
def set_seed(seed):
    np.random.seed(seed)
    torch.manual_seed(seed)
    random.seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

set_seed(42)

# %%
data_video = np.load("final_features/video_features_and_labels.npz")
features_video = data_video["features"]
labels_video = data_video["labels"]
print(features_video.shape)
# Out:
# (309, 128)

# %%
data_transcription = np.load("final_features/transcription_features_and_labels.npz")
features_transcription = data_transcription["features"]
labels_transcription = data_transcription["labels"]
print(features_transcription.shape)
# Out:
# (309, 64)

# %%
data_audio = np.load("final_features/audio_features_and_labels.npz")
features_audio = data_audio["features"]
labels_audio = data_audio["labels"]
print(features_audio.shape)
# Out:
# (309, 20)

# %%
final_features = np.hstack((features_video, features_transcription, features_audio))

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
final_features = scaler.fit_transform(final_features)

# %%
dataset = TensorDataset(torch.tensor(final_features, dtype=torch.float32), torch.tensor(labels_video, dtype=torch.float32))
dataset_loader = DataLoader(dataset, batch_size=32, shuffle=False)

train_size = int(0.7 * len(dataset))  # 70% para entrenamiento
val_size = int(0.15 * len(dataset))   # 15% para validación
test_size = len(dataset) - train_size - val_size  # 15% para prueba

train, val, test = random_split(dataset, [train_size, val_size, test_size])

batch_size = 4
train_loader = DataLoader(train, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test, batch_size=batch_size, shuffle=False)

# %%
device = torch.device("mps") if torch.backends.mps.is_available() else torch.device("cpu")
if torch.cuda.is_available():
    device = torch.device("cuda")
print(device)
# Out:
# cuda

# %%
def evaluar_modelo_1(model, test_loader,path):
    model.load_state_dict(torch.load(path, weights_only=True))
    model.to(device)  
    model.eval()  # Poner el modelo en modo evaluación

    correct = 0
    total = 0
    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            output = model(x_batch)
            probs = torch.sigmoid(output)
            preds = (probs >= 0.5).float()  # Convertir en 0 o 1
            correct += (preds == y_batch).sum().item()
            total += y_batch.size(0)

    print(f"Total ejemplos en test: {total}")
    acc = correct / total
    print(f"Precisión en prueba: {acc:.4f}")

# %%
class MultimodalClassifier(nn.Module):
    def __init__(self, hidden_dim=512, input_dim=212):  
        super().__init__()
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.GELU(),
            nn.LayerNorm(hidden_dim),
            nn.Dropout(0.3),

            nn.Linear(512, 256),
            nn.GELU(),
            nn.LayerNorm(256),
            nn.Dropout(0.3),


            
            nn.Linear(256, 128),
            nn.GELU(),
            nn.LayerNorm(128),
            nn.Dropout(0.3),

            nn.Linear(128, 1)  
        )

    def forward(self, x):
        return self.classifier(x)

# %%
# Crear el modelo y definir todo
model = MultimodalClassifier().to(device)
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.AdamW(model.parameters(), lr=1e-4)
scheduler = ReduceLROnPlateau(optimizer,
                              mode='max',      
                              patience=5,
                              factor=0.3,)

best_acc = 0.0  
best_model_path = "concat_final_model.pth"  

# Early Stopping
patience = 100
no_improve = 0

num_epochs = 1000
for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    
    for X_batch, y_batch in train_loader:
        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)

        optimizer.zero_grad()
        y_pred = model(X_batch)  
        loss = criterion(y_pred, y_batch)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for x_batch, y_batch in val_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            output = model(x_batch)
            probs = torch.sigmoid(output)
            preds = (probs >= 0.5).float()
            correct += (preds == y_batch).sum().item()
            total += y_batch.size(0)

    acc = correct / total
    scheduler.step(acc)
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {total_loss/len(train_loader):.4f}, Val Acc: {acc:.4f}")

    if acc > best_acc:
        best_acc = acc
        torch.save(model.state_dict(), best_model_path)
        print(f"Mejores pesos guardados con precisión: {best_acc:.4f}")
        no_improve = 0  # reinicia el contador
    else:
        no_improve += 1
        print(f"No mejora por {no_improve}/{patience} épocas")

    if no_improve >= patience:
        print(f"Early stopping activado en la época {epoch+1}")
        break
# Out:
# Epoch 1/1000, Loss: 0.2364, Val Acc: 0.7174
# Mejores pesos guardados con precisión: 0.7174
# Epoch 2/1000, Loss: 0.0493, Val Acc: 0.7174
# No mejora por 1/100 épocas
# Epoch 3/1000, Loss: 0.0263, Val Acc: 0.7174
# No mejora por 2/100 épocas
# Epoch 4/1000, Loss: 0.0213, Val Acc: 0.7174
# No mejora por 3/100 épocas
# Epoch 5/1000, Loss: 0.0131, Val Acc: 0.7174
# No mejora por 4/100 épocas
# Epoch 6/1000, Loss: 0.0118, Val Acc: 0.7391
# Mejores pesos guardados con precisión: 0.7391
# Epoch 7/1000, Loss: 0.0097, Val Acc: 0.7391
# No mejora por 1/100 épocas
# Epoch 8/1000, Loss: 0.0082, Val Acc: 0.7391
# No mejora por 2/100 épocas
# Epoch 9/1000, Loss: 0.0063, Val Acc: 0.7391
# No mejora por 3/100 épocas
# Epoch 10/1000, Loss: 0.0051, Val Acc: 0.7391
# No mejora por 4/100 épocas
# Epoch 11/1000, Loss: 0.0048, Val Acc: 0.7391
# No mejora por 5/100 épocas
# Epoch 12/1000, Loss: 0.0053, Val Acc: 0.7391
# No mejora por 6/100 épocas
# Epoch 13/1000, Loss: 0.0042, Val Acc: 0.7391
# No mejora por 7/100 épocas
# Epoch 14/1000, Loss: 0.0042, Val Acc: 0.7391
# No mejora por 8/100 épocas
# Epoch 15/1000, Loss: 0.0042, Val Acc: 0.7391
# No mejora por 9/100 épocas
# Epoch 16/1000, Loss: 0.0038, Val Acc: 0.7391
# No mejora por 10/100 épocas
# Epoch 17/1000, Loss: 0.0037, Val Acc: 0.7391
# No mejora por 11/100 épocas
# Epoch 18/1000, Loss: 0.0039, Val Acc: 0.7391
# No mejora por 12/100 épocas
# Epoch 19/1000, Loss: 0.0034, Val Acc: 0.7391
# No mejora por 13/100 épocas
# Epoch 20/1000, Loss: 0.0038, Val Acc: 0.7391
# No mejora por 14/100 épocas
# Epoch 21/1000, Loss: 0.0037, Val Acc: 0.7391
# No mejora por 15/100 épocas
# Epoch 22/1000, Loss: 0.0035, Val Acc: 0.7391
# No mejora por 16/100 épocas
# Epoch 23/1000, Loss: 0.0035, Val Acc: 0.7391
# No mejora por 17/100 épocas
# Epoch 24/1000, Loss: 0.0036, Val Acc: 0.7391
# No mejora por 18/100 épocas
# Epoch 25/1000, Loss: 0.0036, Val Acc: 0.7391
# No mejora por 19/100 épocas
# Epoch 26/1000, Loss: 0.0034, Val Acc: 0.7391
# No mejora por 20/100 épocas
# Epoch 27/1000, Loss: 0.0038, Val Acc: 0.7391
# No mejora por 21/100 épocas
# Epoch 28/1000, Loss: 0.0031, Val Acc: 0.7391
# No mejora por 22/100 épocas
# Epoch 29/1000, Loss: 0.0034, Val Acc: 0.7391
# No mejora por 23/100 épocas
# Epoch 30/1000, Loss: 0.0033, Val Acc: 0.7391
# No mejora por 24/100 épocas
# Epoch 31/1000, Loss: 0.0036, Val Acc: 0.7391
# No mejora por 25/100 épocas
# Epoch 32/1000, Loss: 0.0030, Val Acc: 0.7391
# No mejora por 26/100 épocas
# Epoch 33/1000, Loss: 0.0034, Val Acc: 0.7391
# No mejora por 27/100 épocas
# Epoch 34/1000, Loss: 0.0032, Val Acc: 0.7391
# No mejora por 28/100 épocas
# Epoch 35/1000, Loss: 0.0033, Val Acc: 0.7391
# No mejora por 29/100 épocas
# Epoch 36/1000, Loss: 0.0032, Val Acc: 0.7391
# No mejora por 30/100 épocas
# Epoch 37/1000, Loss: 0.0034, Val Acc: 0.7391
# No mejora por 31/100 épocas
# Epoch 38/1000, Loss: 0.0034, Val Acc: 0.7391
# No mejora por 32/100 épocas
# Epoch 39/1000, Loss: 0.0031, Val Acc: 0.7391
# No mejora por 33/100 épocas
# Epoch 40/1000, Loss: 0.0033, Val Acc: 0.7391
# No mejora por 34/100 épocas
# Epoch 41/1000, Loss: 0.0034, Val Acc: 0.7391
# No mejora por 35/100 épocas
# Epoch 42/1000, Loss: 0.0033, Val Acc: 0.7391
# No mejora por 36/100 épocas
# Epoch 43/1000, Loss: 0.0031, Val Acc: 0.7391
# No mejora por 37/100 épocas
# Epoch 44/1000, Loss: 0.0035, Val Acc: 0.7391
# No mejora por 38/100 épocas
# Epoch 45/1000, Loss: 0.0039, Val Acc: 0.7391
# No mejora por 39/100 épocas
# Epoch 46/1000, Loss: 0.0034, Val Acc: 0.7391
# No mejora por 40/100 épocas
# Epoch 47/1000, Loss: 0.0032, Val Acc: 0.7391
# No mejora por 41/100 épocas
# Epoch 48/1000, Loss: 0.0032, Val Acc: 0.7391
# No mejora por 42/100 épocas
# Epoch 49/1000, Loss: 0.0032, Val Acc: 0.7391
# No mejora por 43/100 épocas
# Epoch 50/1000, Loss: 0.0032, Val Acc: 0.7391
# No mejora por 44/100 épocas
# Epoch 51/1000, Loss: 0.0035, Val Acc: 0.7391
# No mejora por 45/100 épocas
# Epoch 52/1000, Loss: 0.0036, Val Acc: 0.7391
# No mejora por 46/100 épocas
# Epoch 53/1000, Loss: 0.0031, Val Acc: 0.7391
# No mejora por 47/100 épocas
# Epoch 54/1000, Loss: 0.0035, Val Acc: 0.7391
# No mejora por 48/100 épocas
# Epoch 55/1000, Loss: 0.0032, Val Acc: 0.7391
# No mejora por 49/100 épocas
# Epoch 56/1000, Loss: 0.0032, Val Acc: 0.7391
# No mejora por 50/100 épocas
# Epoch 57/1000, Loss: 0.0030, Val Acc: 0.7391
# No mejora por 51/100 épocas
# Epoch 58/1000, Loss: 0.0031, Val Acc: 0.7391
# No mejora por 52/100 épocas
# Epoch 59/1000, Loss: 0.0032, Val Acc: 0.7391
# No mejora por 53/100 épocas
# Epoch 60/1000, Loss: 0.0034, Val Acc: 0.7391
# No mejora por 54/100 épocas
# Epoch 61/1000, Loss: 0.0032, Val Acc: 0.7391
# No mejora por 55/100 épocas
# Epoch 62/1000, Loss: 0.0032, Val Acc: 0.7391
# No mejora por 56/100 épocas
# Epoch 63/1000, Loss: 0.0034, Val Acc: 0.7391
# No mejora por 57/100 épocas
# Epoch 64/1000, Loss: 0.0034, Val Acc: 0.7391
# No mejora por 58/100 épocas
# Epoch 65/1000, Loss: 0.0031, Val Acc: 0.7391
# No mejora por 59/100 épocas
# Epoch 66/1000, Loss: 0.0035, Val Acc: 0.7391
# No mejora por 60/100 épocas
# Epoch 67/1000, Loss: 0.0033, Val Acc: 0.7391
# No mejora por 61/100 épocas
# Epoch 68/1000, Loss: 0.0032, Val Acc: 0.7391
# No mejora por 62/100 épocas
# Epoch 69/1000, Loss: 0.0032, Val Acc: 0.7391
# No mejora por 63/100 épocas
# Epoch 70/1000, Loss: 0.0035, Val Acc: 0.7391
# No mejora por 64/100 épocas
# Epoch 71/1000, Loss: 0.0033, Val Acc: 0.7391
# No mejora por 65/100 épocas
# Epoch 72/1000, Loss: 0.0031, Val Acc: 0.7391
# No mejora por 66/100 épocas
# Epoch 73/1000, Loss: 0.0035, Val Acc: 0.7391
# No mejora por 67/100 épocas
# Epoch 74/1000, Loss: 0.0035, Val Acc: 0.7391
# No mejora por 68/100 épocas
# Epoch 75/1000, Loss: 0.0032, Val Acc: 0.7391
# No mejora por 69/100 épocas
# Epoch 76/1000, Loss: 0.0033, Val Acc: 0.7391
# No mejora por 70/100 épocas
# Epoch 77/1000, Loss: 0.0032, Val Acc: 0.7391
# No mejora por 71/100 épocas
# Epoch 78/1000, Loss: 0.0035, Val Acc: 0.7391
# No mejora por 72/100 épocas
# Epoch 79/1000, Loss: 0.0034, Val Acc: 0.7391
# No mejora por 73/100 épocas
# Epoch 80/1000, Loss: 0.0031, Val Acc: 0.7391
# No mejora por 74/100 épocas
# Epoch 81/1000, Loss: 0.0035, Val Acc: 0.7391
# No mejora por 75/100 épocas
# Epoch 82/1000, Loss: 0.0031, Val Acc: 0.7391
# No mejora por 76/100 épocas
# Epoch 83/1000, Loss: 0.0033, Val Acc: 0.7391
# No mejora por 77/100 épocas
# Epoch 84/1000, Loss: 0.0037, Val Acc: 0.7391
# No mejora por 78/100 épocas
# Epoch 85/1000, Loss: 0.0036, Val Acc: 0.7391
# No mejora por 79/100 épocas
# Epoch 86/1000, Loss: 0.0034, Val Acc: 0.7391
# No mejora por 80/100 épocas
# Epoch 87/1000, Loss: 0.0032, Val Acc: 0.7391
# No mejora por 81/100 épocas
# Epoch 88/1000, Loss: 0.0033, Val Acc: 0.7391
# No mejora por 82/100 épocas
# Epoch 89/1000, Loss: 0.0030, Val Acc: 0.7391
# No mejora por 83/100 épocas
# Epoch 90/1000, Loss: 0.0030, Val Acc: 0.7391
# No mejora por 84/100 épocas
# Epoch 91/1000, Loss: 0.0030, Val Acc: 0.7391
# No mejora por 85/100 épocas
# Epoch 92/1000, Loss: 0.0033, Val Acc: 0.7391
# No mejora por 86/100 épocas
# Epoch 93/1000, Loss: 0.0035, Val Acc: 0.7391
# No mejora por 87/100 épocas
# Epoch 94/1000, Loss: 0.0032, Val Acc: 0.7391
# No mejora por 88/100 épocas
# Epoch 95/1000, Loss: 0.0036, Val Acc: 0.7391
# No mejora por 89/100 épocas
# Epoch 96/1000, Loss: 0.0032, Val Acc: 0.7391
# No mejora por 90/100 épocas
# Epoch 97/1000, Loss: 0.0032, Val Acc: 0.7391
# No mejora por 91/100 épocas
# Epoch 98/1000, Loss: 0.0035, Val Acc: 0.7391
# No mejora por 92/100 épocas
# Epoch 99/1000, Loss: 0.0034, Val Acc: 0.7391
# No mejora por 93/100 épocas
# Epoch 100/1000, Loss: 0.0033, Val Acc: 0.7391
# No mejora por 94/100 épocas
# Epoch 101/1000, Loss: 0.0033, Val Acc: 0.7391
# No mejora por 95/100 épocas
# Epoch 102/1000, Loss: 0.0032, Val Acc: 0.7391
# No mejora por 96/100 épocas
# Epoch 103/1000, Loss: 0.0034, Val Acc: 0.7391
# No mejora por 97/100 épocas
# Epoch 104/1000, Loss: 0.0034, Val Acc: 0.7391
# No mejora por 98/100 épocas
# Epoch 105/1000, Loss: 0.0037, Val Acc: 0.7391
# No mejora por 99/100 épocas
# Epoch 106/1000, Loss: 0.0034, Val Acc: 0.7391
# No mejora por 100/100 épocas
# Early stopping activado en la época 106

# %%
evaluar_modelo_1(model,test_loader, path="concat_final_model.pth")
# Out:
# Total ejemplos en test: 47
# Precisión en prueba: 0.6809
